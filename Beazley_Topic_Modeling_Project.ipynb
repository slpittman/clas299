// %%
val url = "http://shot.holycross.edu/ada-vases.tsv"
// Out:
// url: String = "http://shot.holycross.edu/ada-vases.tsv"

// %%
import scala.io.Source
val lines = Source.fromURL(url).getLines.toVector
lines.size
// Out:
// import scala.io.Source
//
// lines: Vector[String] = Vector(
//   "URI\tVase Number\tFabric\tTechnique\tSub Technique\tShape Name\tProvenance\tDate\tInscriptions\t Attributed To\t Decoration\t Collection Record\t Publication Record\t Inscriptions II\tMeasurements\tVolume\tWeight\tRestorations\tOrnament\t Technical Observations\tPleiades URI\tLatitude\tLongitude",
//   "<a href=\"http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04</a>\t1\tATHENIAN\tBLACK-FIGURE\t\tAMPHORA, NECK\tITALY, ETRURIA, VULCI\t-550 to -500\t\tCHIUSI P by KUNZE-GOTTE | LEAGROS GROUP by KUNZE-GOTTE\tA,B: TRIPTOLEMOS ON WINGED CHARIOT BETWEEN DEMETER AND PERSEPHONE\tMunich, Antikensammlungen: J543 | Rome, Candelori Collection | Munich, Antikensammlungen: 1539\tCorpus Vasorum Antiquorum: MUNICH, MUSEUM ANTIKER KLEINKUNST 8, 56-57, BEILAGE D4, PLS.(1816,1820,1830) 398.4,402.1-2,412.2 <a target=_blank href=browseCVARecord.asp?id={8C5C25CA-9E1C-41A2-886A-2558611DCA04}&startRef=>View Whole CVA Plates</a> | Crouwel, J.H., Chariots and other Wheeled Vehicles in Iron Age Greece, Allard Pierson Series 9 (Amsterdam, 1992): PL.26.3 (DRAWING OF PART) | Jahrbuch des Deutschen Archaologischen Instituts: 87 (1972), 81, FIGS.12, 13 (A, B)\t\t\t\t\t\t\t\t<a href=\"https://pleiades.stoa.org/places/413393\" target=\"_blank\">https://pleiades.stoa.org/places/413393</a>\t42.421429\t11.702499",
//   "<a href=\"http://www.beazley.ox.ac.uk/record/669B79A6-CACA-4CCA-8E0C-69D2C4C9172F\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/669B79A6-CACA-4CCA-8E0C-69D2C4C9172F</a>\t2\tATHENIAN\tBLACK-FIGURE\t\tKRATER, COLUMN FRAGMENT\tATHENS, AGORA\t-550 to -500\t\t\tUnder handle: VOLUTE KRATER\tAthens, Agora Museum: P13332\tThe Athenian Agora, Results of Excavations conducted by the American School of Classical Studies at Athens: 23, PL.44.463\t\t\t\t\t\t\t\t<a href=\"https://pleiades.stoa.org/places/807514119\" target=\"_blank\">https://pleiades.stoa.org/places/807514119</a>\t37.995486\t23.731327",
//   "<a href=\"http://www.beazley.ox.ac.uk/record/B7867649-B68A-4152-8243-15FCE35031C9\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/B7867649-B68A-4152-8243-15FCE35031C9</a>\t3\tATHENIAN\tBLACK-FIGURE\t\tAMPHORA, NECK\tITALY, ETRURIA, VULCI\t\t\t\tA,B: TRIPTOLEMOS AND DEMETER\tRome, Mus. Naz. Etrusco di Villa Giulia: 63614\tJahrbuch des Deutschen Archaologischen Instituts: 87 (1972), 80, FIGS.8, 9 (A, B) | Lexicon Iconographicum Mythologiae Classicae: VIII, PL.34, TRIPTOLEMOS 63 (A) | Regoli, C. (ed.) Mode e Modelli, Fortuna e insuccesso nella circolazione di cose e idee (Rome, 2012): 201, FIG.4 (A) | Riccioni, G., Vasi Greci da Vulci, Necropoli dell'Osteria scavi Ferraguti-Mengarelli 1929-1931 (Milan, 2003): FIGS.20-21 (A, B)\t\t\t\t\t\t\t\t<a href=\"https://pleiades.stoa.org/places/413393\" target=\"_blank\">https://pleiades.stoa.org/places/413393</a>\t42.421429\t11.702499",
// ...
// res1_2: Int = 117751

// %%
val byColumns = lines.map(ln => ln.split("\t").toVector)
byColumns.size
// Out:
// byColumns: Vector[Vector[String]] = Vector(
//   Vector(
//     "URI",
//     "Vase Number",
//     "Fabric",
//     "Technique",
//     "Sub Technique",
//     "Shape Name",
//     "Provenance",
//     "Date",
//     "Inscriptions",
//     " Attributed To",
//     " Decoration",
//     " Collection Record",
//     " Publication Record",
//     " Inscriptions II",
//     "Measurements",
//     "Volume",
//     "Weight",
//     "Restorations",
//     "Ornament",
//     " Technical Observations",
//     "Pleiades URI",
//     "Latitude",
//     "Longitude"
//   ),
//   Vector(
//     "<a href=\"http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04</a>",
//     "1",
//     "ATHENIAN",
//     "BLACK-FIGURE",
//     "",
//     "AMPHORA, NECK",
//     "ITALY, ETRURIA, VULCI",
//     "-550 to -500",
//     "",
//     "CHIUSI P by KUNZE-GOTTE | LEAGROS GROUP by KUNZE-GOTTE",
// ...
// res2_1: Int = 117751

// %%
val descriptions = byColumns.filter(row => row.size == 23).map( v => v(10))
// Out:
// descriptions: Vector[String] = Vector(
//   " Decoration",
//   "A,B: TRIPTOLEMOS ON WINGED CHARIOT BETWEEN DEMETER AND PERSEPHONE",
//   "Under handle: VOLUTE KRATER",
//   "A,B: TRIPTOLEMOS AND DEMETER",
//   "A: ATHENA",
//   "Body: CHILD AND HARE",
//   "A: ATHENA, BETWEEN COLUMNS, SHIELD DEVICE, DISCS | B: MUSIC, YOUTH ON PLATFORM PLAYING PIPES BETWEEN JUDGES, SEATED",
//   "WOMAN AND SATYR",
//   "A: GIGANTOMACHY (?) HERAKLES AND ATHENA IN CHARIOT, WARRIOR, NONSENSE INSCRIPTIONS | B: HERAKLES PLAYING KITHARA AT ALTAR, IOLAOS, WOMAN, ATHENA, SHIELD DEVICE, SNAKE, NONSENSE INSCRIPTIONS | Under foot: GRAFFITO: MAN, SWASTIKA",
//   "A: MAN WITH PHIALE AND STAFF, WOMAN WITH OINOCHOE | B: WOMAN",
//   "A: SWAN BETWEEN LIONS | B: SIRENS | Neck A: SIREN | Neck B: LION",
//   "A: DIONYSOS, SATYRS, ONE WITH LYRE AND MAENAD WITH PIPES, IN SHIP | B: DIONYSOS, MAENADS AND SATYRS IN SHIP",
//   "Body: SPHINX, LIONS",
//   "Body: WEDDED PAIR IN CHARIOT, WOMEN, YOUTHS WITH HYDRIA AND KITHARA, OLD MAN SEATED | Predella: PANTHERS, DEER | Shoulder: THESEUS (IN NEBRIS) AND MINOTAUR BETWEEN ONLOOKERS (YOUTHS, SOME DRAPED, SOME WITH WREATHS), FILLETS SUSPENDED",
//   "Body: HERAKLES AND TRITON | Predella: PANTHERS, DEER | Shoulder: YOUTHS LEADING HORSES",
//   "Body: CHARIOT (CHARIOTEER IN NEBRIS), YOUTH | Shoulder: ACHILLES AND TROILOS, WOMAN AT FOUNTAIN, POLYXENE, AND YOUTH RUNNING",
//   "A: MEN DANCING (?)",
//   "DRAPED MEN, CHARIOT, HORSE, PALMETTE",
//   "A: WOMAN RUNNING WITH TORCHES | B: WOMAN RUNNING WITH BOX",
//   "A,B: GORGONEION",
//   "I: ATHENA HOLDING HELMET, SHIELD, STELE",
//   "I: MAN LEANING ON STAFF (?) FIGURE SEATED (?) ON STOOL",
//   "A: GORGONEION",
//   "A,B: GORGONEION",
//   "A: MAN, DRAWING WATER FROM PITHOS, WOMAN WITH HYDRIAI, SATYR MASTURBATING, MAENAD | B: HERAKLES AND THE BULL",
//   "A: ATHENA, NIKE",
//   "KOMOS",
//   "FLORAL, IVY CHAIN, LAUREL WREATH",
//   "Body: COCKS",
// ...

// %%
val tidier = descriptions.map(t => t.toLowerCase).map(descr => descr.replaceAll("[^a-z ]", ""))
// Out:
// tidier: Vector[String] = Vector(
//   " decoration",
//   "ab triptolemos on winged chariot between demeter and persephone",
//   "under handle volute krater",
//   "ab triptolemos and demeter",
//   "a athena",
//   "body child and hare",
//   "a athena between columns shield device discs  b music youth on platform playing pipes between judges seated",
//   "woman and satyr",
//   "a gigantomachy  herakles and athena in chariot warrior nonsense inscriptions  b herakles playing kithara at altar iolaos woman athena shield device snake nonsense inscriptions  under foot graffito man swastika",
//   "a man with phiale and staff woman with oinochoe  b woman",
//   "a swan between lions  b sirens  neck a siren  neck b lion",
//   "a dionysos satyrs one with lyre and maenad with pipes in ship  b dionysos maenads and satyrs in ship",
//   "body sphinx lions",
//   "body wedded pair in chariot women youths with hydria and kithara old man seated  predella panthers deer  shoulder theseus in nebris and minotaur between onlookers youths some draped some with wreaths fillets suspended",
//   "body herakles and triton  predella panthers deer  shoulder youths leading horses",
//   "body chariot charioteer in nebris youth  shoulder achilles and troilos woman at fountain polyxene and youth running",
//   "a men dancing ",
//   "draped men chariot horse palmette",
//   "a woman running with torches  b woman running with box",
//   "ab gorgoneion",
//   "i athena holding helmet shield stele",
//   "i man leaning on staff  figure seated  on stool",
//   "a gorgoneion",
//   "ab gorgoneion",
//   "a man drawing water from pithos woman with hydriai satyr masturbating maenad  b herakles and the bull",
//   "a athena nike",
//   "komos",
//   "floral ivy chain laurel wreath",
//   "body cocks",
// ...

// %%
val k = 10
val iterations = 20
val stopWords = Array("the", "a", "and", "with", "holding", "for", "into", "between", "among")
val vocabSize = 10000
val minimumTokenLength = 3
val termsToDisplay = 15
// Out:
// k: Int = 10
// iterations: Int = 20
// stopWords: Array[String] = Array(
//   "the",
//   "a",
//   "and",
//   "with",
//   "holding",
//   "for",
//   "into",
//   "between",
//   "among"
// )
// vocabSize: Int = 10000
// minimumTokenLength: Int = 3
// termsToDisplay: Int = 15

// %%
import $ivy.`org.apache.spark::spark-sql:2.4.5`
import org.apache.spark.sql._
import $ivy.`org.apache.spark::spark-mllib:2.4.5`
// Out:
// import $ivy.$
//
// import org.apache.spark.sql._
//
// import $ivy.$

// %%
import org.apache.log4j.{Level, Logger}
Logger.getLogger("org").setLevel(Level.OFF)
// Out:
// import org.apache.log4j.{Level, Logger}

// %%
val spark = {
  NotebookSparkSession.builder()
    .master("local[*]")
    .getOrCreate()
}
// Out:
// Loading spark-stubs
// Getting spark JARs
// Creating SparkSession
// Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
// <a href="http://jupyter-slpittman-2dclas299-2do6xbmpss:4040">Spark UI</a>
// spark: SparkSession = org.apache.spark.sql.SparkSession@759c9384

// %%
import org.apache.spark.ml.clustering.LDA
import org.apache.spark.ml.feature.RegexTokenizer
import org.apache.spark.ml.feature.StopWordsRemover
import org.apache.spark.ml.feature.CountVectorizer
import org.apache.spark.mllib.linalg.Vector
import scala.collection.mutable.WrappedArray
import org.apache.spark.sql.types.IntegerType
import org.apache.spark.sql.functions._
// Out:
// import org.apache.spark.ml.clustering.LDA
//
// import org.apache.spark.ml.feature.RegexTokenizer
//
// import org.apache.spark.ml.feature.StopWordsRemover
//
// import org.apache.spark.ml.feature.CountVectorizer
//
// import org.apache.spark.mllib.linalg.Vector
//
// import scala.collection.mutable.WrappedArray
//
// import org.apache.spark.sql.types.IntegerType
//
// import org.apache.spark.sql.functions._

// %%
val txtRdd = spark.sparkContext.parallelize(tidier).zipWithIndex
// Out:
// <script>
// var comm = Jupyter.notebook.kernel.comm_manager.new_comm('cancel-stage-5c07561c-8ee7-4dec-9fdd-75e660d02add', {});
//
// function cancelStage(stageId) {
//   console.log('Cancelling stage ' + stageId);
//   comm.send({ 'stageId': stageId });
// }
// </script>
// <div>
//   <span style="float: left;">zipWithIndex at cmd10.sc:1</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// txtRdd: org.apache.spark.rdd.RDD[(String, Long)] = ZippedWithIndexRDD[1] at zipWithIndex at cmd10.sc:1

// %%
import spark.sqlContext.implicits._

val corpus_df = txtRdd.toDF("corpus", "id")
// Out:
// import spark.sqlContext.implicits._
//
//
// corpus_df: DataFrame = [corpus: string, id: bigint]

// %%
implicit class RichDF(val df: DataFrame) {
  def showHTML(limit:Int = 20, truncate: Int = 20) = {
    import xml.Utility.escape
    val data = df.take(limit)
    val header = df.schema.fieldNames.toSeq
    val rows: Seq[Seq[String]] = data.map { row =>
      row.toSeq.map { cell =>
        val str = cell match {
          case null => "null"
          case binary: Array[Byte] => binary.map("%02X".format(_)).mkString("[", " ", "]")
          case array: Array[_] => array.mkString("[", ", ", "]")
          case seq: Seq[_] => seq.mkString("[", ", ", "]")
          case _ => cell.toString
        }
        if (truncate > 0 && str.length > truncate) {
          if (truncate < 4) str.substring(0, truncate)
          else str.substring(0, truncate - 3) + "..."
        } else {
          str
        }
      }: Seq[String]
    }

    publish.html(s"""
      <table class="table">
        <tr>
        ${header.map(h => s"<th>${escape(h)}</th>").mkString}
        </tr>
        ${rows.map { row =>
          s"<tr>${row.map { c => s"<td>${escape(c)}</td>" }.mkString}</tr>"
        }.mkString
        }
      </table>""")
  }
}
// Out:
// defined class RichDF

// %%
val tokenizer = new RegexTokenizer().setPattern("[\\W_]+").setMinTokenLength(minimumTokenLength).setInputCol("corpus").setOutputCol("tokens")
val tokenized_df = tokenizer.transform(corpus_df)
// Out:
// tokenizer: RegexTokenizer = regexTok_58ca5b21f774
// tokenized_df: DataFrame = [corpus: string, id: bigint ... 1 more field]

// %%
val remover = new StopWordsRemover().setStopWords(stopWords).setInputCol("tokens").setOutputCol("filtered")
val filtered_df = remover.transform(tokenized_df)
// Out:
// remover: StopWordsRemover = stopWords_95e7ecfea0b7
// filtered_df: DataFrame = [corpus: string, id: bigint ... 2 more fields]

// %%
val vectorizer = new CountVectorizer().setInputCol("filtered").setOutputCol("features").setVocabSize(vocabSize).setMinDF(5).fit(filtered_df)
val countVectors = vectorizer.transform(filtered_df).select("id", "features")
// Out:
// <div>
//   <span style="float: left;">flatMap at CountVectorizer.scala:205</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">count at CountVectorizer.scala:230</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">top at CountVectorizer.scala:233</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// vectorizer: org.apache.spark.ml.feature.CountVectorizerModel = cntVec_7d0239c3653b
// countVectors: DataFrame = [id: bigint, features: vector]

// %%
val lda = new LDA().setK(k).setMaxIter(iterations)
val model = lda.fit(countVectors)
// Out:
// <div>
//   <span style="float: left;">count at LDAOptimizer.scala:419</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">first at LDAOptimizer.scala:420</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// 20/04/28 00:36:43 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeSystemBLAS
// 20/04/28 00:36:43 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeRefBLAS
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// lda: LDA = lda_2f0495df36fa
// model: org.apache.spark.ml.clustering.LDAModel = lda_2f0495df36fa

// %%
val topics = model.describeTopics(termsToDisplay)
// Out:
// topics: DataFrame = [topic: int, termIndices: array<int> ... 1 more field]

// %%
topics.showHTML(truncate=1000)
// Out:
//       <table class="table">
//         <tr>
//         <th>topic</th><th>termIndices</th><th>termWeights</th>
//         </tr>
//         <tr><td>0</td><td>[4, 5, 1, 2, 12, 0, 17, 7, 40, 68, 81, 97, 9, 53, 30]</td><td>[0.10217044777538202, 0.08723919905314466, 0.06849469157878478, 0.05334493460440521, 0.05240107534790209, 0.036671366471885396, 0.025226322501318593, 0.01825991895027679, 0.017456644723519963, 0.01639031233766903, 0.015430888314454636, 0.013958617749564991, 0.013953478716707593, 0.01343543834906955, 0.013311167633103152]</td></tr><tr><td>1</td><td>[216, 0, 402, 32, 327, 333, 148, 77, 275, 411, 173, 389, 426, 560, 457]</td><td>[0.028038460439560677, 0.0231267296891423, 0.01957012013944126, 0.015473383539968997, 0.014440274440285693, 0.013555782023828757, 0.013259061873813975, 0.012653732947355802, 0.01236677736838375, 0.01225463593510228, 0.011028472160905167, 0.009239870499893358, 0.008503810861178867, 0.008487417941722948, 0.00810230834588029]</td></tr><tr><td>2</td><td>[11, 0, 22, 35, 31, 26, 36, 13, 33, 52, 48, 45, 49, 37, 3]</td><td>[0.051991383119690725, 0.03491040052215448, 0.033831389398996554, 0.03295527399403386, 0.03239951113418064, 0.03178467149583517, 0.029456665388734208, 0.02742855273588718, 0.026621563416533982, 0.02569177963849335, 0.02568013710344211, 0.02523175051425553, 0.02436094783451919, 0.024283662641159044, 0.022239338597908997]</td></tr><tr><td>3</td><td>[14, 28, 0, 41, 54, 60, 91, 23, 124, 50, 100, 171, 143, 238, 212]</td><td>[0.16522224462446197, 0.10779809879871713, 0.09653496844170119, 0.07072641348325823, 0.06841555847888862, 0.06454195455370038, 0.04280206701910054, 0.0348762903674773, 0.019959520411260506, 0.017743778754110935, 0.012426968605120667, 0.009677232669848811, 0.00819635469544626, 0.007901432465569309, 0.007594454420192876]</td></tr><tr><td>4</td><td>[9, 1, 79, 89, 0, 19, 27, 132, 68, 168, 18, 175, 23, 250, 196]</td><td>[0.21256051260471598, 0.09756159855380767, 0.032085228934496356, 0.028686215297332375, 0.026450479405920203, 0.025561514305534317, 0.01758799394984439, 0.017506148174299987, 0.016662370060121744, 0.016243305576988585, 0.014436871960121533, 0.013684910477681849, 0.013443670234473444, 0.011568961107262759, 0.009309228548304902]</td></tr><tr><td>5</td><td>[3, 2, 0, 1, 7, 8, 6, 4, 18, 16, 10, 5, 21, 56, 66]</td><td>[0.06892314933668833, 0.06431410922003056, 0.061319386205208694, 0.0541362741691426, 0.039354684233885766, 0.03613186340045621, 0.03492641605060616, 0.032506822194804996, 0.01912316423206213, 0.018331696104759338, 0.0162470178746295, 0.015053790230766218, 0.01256441706803284, 0.011173248626868793, 0.011065228024659616]</td></tr><tr><td>6</td><td>[13, 20, 43, 11, 155, 0, 232, 26, 71, 17, 7, 82, 255, 111, 184]</td><td>[0.12215833709716628, 0.11652289142429409, 0.07976822083658981, 0.035683571940653754, 0.021630512346577233, 0.020176280018446468, 0.016289879641347146, 0.01626535828443576, 0.015308241571681556, 0.014408313546852713, 0.013032247916781047, 0.012025659910671284, 0.011971264246767374, 0.011835759706613628, 0.011366828190907022]</td></tr><tr><td>7</td><td>[84, 109, 0, 315, 139, 176, 203, 427, 204, 310, 414, 478, 360, 364, 15]</td><td>[0.06354976818081397, 0.03587998541274356, 0.021971821422119026, 0.018350879069352247, 0.01829202945402016, 0.015653419887803166, 0.015557615533180783, 0.013075831610040415, 0.013012514549725929, 0.012590809047934949, 0.012307045616221726, 0.011307000828625848, 0.010066594792501502, 0.00855081274025792, 0.00799380775684646]</td></tr><tr><td>8</td><td>[1, 6, 47, 10, 5, 0, 4, 3, 51, 67, 16, 21, 72, 87, 17]</td><td>[0.11033719327837452, 0.08060806855730673, 0.04541840466404663, 0.04466752398622531, 0.03161727407438086, 0.031045666729832333, 0.03021234364306015, 0.025680668110915374, 0.02535400401564348, 0.022294689531515945, 0.016818835560678307, 0.015396735149213336, 0.01528332715699342, 0.01526887148848137, 0.015018760555491818]</td></tr><tr><td>9</td><td>[15, 24, 0, 25, 32, 29, 2, 19, 42, 3, 39, 59, 12, 5, 17]</td><td>[0.04543069628991678, 0.03981822795589251, 0.039566225738425456, 0.03470450805515888, 0.027649782524034335, 0.027623298818 ...
//       </table>

// %%
val topicLabels = topics.select("termIndices").map { case Row(r:  WrappedArray[Integer]) => r.map( i => vectorizer.vocabulary(i) ) }
val labelsNumberedLong = topicLabels.rdd.zipWithIndex.toDF("terms", "topicLong")
val labelsIndexed = labelsNumberedLong.withColumn("topic", $"topicLong".cast(IntegerType)).drop("topicLong")

val topicsWithTerms = labelsIndexed.join(topics, labelsIndexed.col("topic") === topics.col("topic")).drop(labelsIndexed.col("topic"))
// Out:
// <div>
//   <span style="float: left;">zipWithIndex at cmd19.sc:2</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// topicLabels: Dataset[WrappedArray[String]] = [value: array<string>]
// labelsNumberedLong: DataFrame = [terms: array<string>, topicLong: bigint]
// labelsIndexed: DataFrame = [terms: array<string>, topic: int]
// topicsWithTerms: DataFrame = [terms: array<string>, topic: int ... 2 more fields]

// %%
val weightedLabels = topicsWithTerms.withColumn("termsWithWeight", expr("zip_with(terms, termWeights, (t,w) -> concat(t, ' ', w))"))
// Out:
// weightedLabels: DataFrame = [terms: array<string>, topic: int ... 3 more fields]

// %%
weightedLabels.select("topic", "termsWithWeight").showHTML(truncate=1000)
// Out:
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     2 / 2
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">take at cmd12.sc:4</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">take at cmd12.sc:4</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
//       <table class="table">
//         <tr>
//         <th>topic</th><th>termsWithWeight</th>
//         </tr>
//         <tr><td>0</td><td>[youth 0.10217044777538202, man 0.08723919905314466, draped 0.06849469157878478, woman 0.05334493460440521, chariot 0.05240107534790209, body 0.036671366471885396, athena 0.025226322501318593, seated 0.01825991895027679, hermes 0.017456644723519963, apollo 0.01639031233766903, winged 0.015430888314454636, mounting 0.013958617749564991, figure 0.013953478716707593, nike 0.01343543834906955, komos 0.013311167633103152]</td></tr><tr><td>1</td><td>[heads 0.028038460439560677, body 0.0231267296891423, griffins 0.01957012013944126, head 0.015473383539968997, arimasp 0.014440274440285693, statue 0.013555782023828757, achilles 0.013259061873813975, lid 0.012653732947355802, hydria 0.01236677736838375, fountain 0.01225463593510228, carrying 0.011028472160905167, huntsman 0.009239870499893358, wheel 0.008503810861178867, arimasps 0.008487417941722948, polyxene 0.00810230834588029]</td></tr><tr><td>2</td><td>[dionysos 0.051991383119690725, body 0.03491040052215448, playing 0.033831389398996554, animal 0.03295527399403386, symposium 0.03239951113418064, satyrs 0.03178467149583517, maenads 0.029456665388734208, satyr 0.02742855273588718, pipes 0.026621563416533982, frieze 0.02569177963849335, reclining 0.02568013710344211, drinking 0.02523175051425553, horn 0.02436094783451919, vine 0.024283662641159044, one 0.022239338597908997]</td></tr><tr><td>3</td><td>[floral 0.16522224462446197, palmette 0.10779809879871713, body 0.09653496844170119, palmettes 0.07072641348325823, chain 0.06841555847888862, lotus 0.06454195455370038, bud 0.04280206701910054, ivy 0.0348762903674773, inscription 0.019959520411260506, wreath 0.017743778754110935, pattern 0.012426968605120667, laurel 0.009677232669848811, sprig 0.00819635469544626, berries 0.007901432465569309, leaf 0.007594454420192876]</td></tr><tr><td>4</td><td>[figure 0.21256051260471598, draped 0.09756159855380767, horseman 0.032085228934496356, tree 0.028686215297332375, body 0.026450479405920203, herakles 0.025561514305534317, running 0.01758799394984439, artemis 0.017506148174299987, apollo 0.016662370060121744, bow 0.016243305576988585, suspended 0.014436871960121533, quiver 0.013684910477681849, ivy 0.013443670234473444, palm 0.011568961107262759, object 0.009309228548304902]</td></tr><tr><td>5</td><td>[one 0.06892314933668833, woman 0.06431410922003056, body 0.061319386205208694, draped 0.0541362741691426, seated 0.039354684233885766, women 0.03613186340045621, youths 0.03492641605060616, youth 0.032506822194804996, suspended 0.01912316423206213, men 0.018331696104759338, staff 0.0162470178746295, man 0.015053790230766218, some 0.01256441706803284, eros 0.011173248626868793, domestic 0.011065228024659616]</td></tr><tr><td>6</td><td>[satyr 0.12215833709716628, maenad 0.11652289142429409, thyrsos 0.07976822083658981, dionysos 0.035683571940653754, gigantomachy 0.021630512346577233, body 0.020176280018446468, giant 0.016289879641347146, satyrs 0.01626535828443576, kantharos 0.015308241571681556, athena 0.014408313546852713, seated 0.013032247916781047, bull 0.012025659910671284, hephaistos 0.011971264246767374, snake 0.011835759706613628, ram 0.011366828190907022]</td></tr><tr><td>7</td><td>[bird 0.06354976818081397, amazon 0.03587998541274356, body 0.021971821422119026, plant 0.018350879069352247, horseback 0.01829202945402016, oriental 0.015653419887803166, costume 0.015557615533180783, goose 0.013075831610040415, griffin 0.013012514549725929, fish 0.012590809047934949, priam 0.012307045616221726, duck 0.011307000828625848, death 0.010066594792501502, hen 0.00855081274025792, warrior 0.00799380775684646]</td></tr><tr><td>8</td><td>[draped 0.11033719327837452, youths 0.08060806855730673, athletes 0.04541840466404663, staff 0.04466752398622531, man 0.03161727407438086, body 0.031045666729832333, youth 0.03021234364306015, one 0.025680668110915374, athlete 0.02535400401564348, figures 0.022294689531515945, men 0.016818835560678307, some 0.015396735149213336, leaning 0.015 ...
//       </table>
